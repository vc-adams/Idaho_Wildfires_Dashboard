# %%
# IMPORT DEPENDENCIES
# FOR DATA
import pandas as pd
import os
import csv
import math
import numpy as np
# import time
# import datetime
# import requests
# import datefinder

# # FOR SQL LITE
# from sqlalchemy import create_engine
# from datetime import date

# # FOR PLOTTING
# import matplotlib.pyplot as plt
# from matplotlib import style
# style.use("fivethirtyeight")
# from matplotlib import rcParams
# rcParams['figure.figsize'] = 10, 8

# FOR MODELING
from scipy.optimize import curve_fit
# from splinter import Browser
# from bs4 import BeautifulSoup as BS
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification

# %% [markdown]
# # IMPORT DATA

# %%
# File path for the CSV Files
idahoFires = os.path.join("..", "Data", "fires_Idaho.csv")

# Open the CSV Files, Convert to a Dataframe, and Save as a Variable
fires_Idaho_df = pd.read_csv(idahoFires)
# fires_Idaho_df = pd.read_csv(idahoFires, dtype={"LOCAL_INCIDENT_ID": 'string', "FIRE_NAME": 'string'})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# View the Data in the Dataframe
# print(fires_Idaho_df.keys())
fires_Idaho_df
# Out:
#        OBJECTID     FOD_ID                   FPA_ID SOURCE_SYSTEM_TYPE  \
# 0           152        155               FS-1419238                FED
# 1           169        172               FS-1419278                FED
# 2           173        176               FS-1419291                FED
# 3           174        177               FS-1419292                FED
# 4           175        178               FS-1419293                FED
# ...         ...        ...                      ...                ...
# 17355   1847559  300274043  SFO-2015IDIDL2202015025             NONFED
# 17356   1847684  300274204  SFO-2015IDIDL2102015023             NONFED
# 17357   1847710  300274236  SFO-2015IDIDL2102015021             NONFED
# 17358   1847762  300274306  SFO-2015IDIDL9802015030             NONFED
# 17359   1848009  300274600  SFO-2015IDIDL2102015024             NONFED
#
#       SOURCE_SYSTEM NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 0       FS-FIRESTAT                    FS                USIDCTF
# 1       FS-FIRESTAT                    FS                USIDCTF
# 2       FS-FIRESTAT                    FS                USIDCTF
# 3       FS-FIRESTAT                    FS                USIDCTF
# 4       FS-FIRESTAT                    FS                USIDCTF
# ...             ...                   ...                    ...
# 17355       ST-NASF                ST/C&L                USIDIDS
# 17356       ST-NASF                ST/C&L                USIDIDS
# 17357       ST-NASF                ST/C&L                USIDIDS
# 17358       ST-NASF                ST/C&L                USIDIDS
# 17359       ST-NASF                ST/C&L                USIDIDS
#
#               NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 0      Caribou-Targhee National Forest                  0415
# 1      Caribou-Targhee National Forest                  0415
# 2      Caribou-Targhee National Forest                  0415
# 3      Caribou-Targhee National Forest                  0415
# 4      Caribou-Targhee National Forest                  0415
# ...                                ...                   ...
# 17355        Idaho Department of Lands                 IDIDL
# 17356        Idaho Department of Lands                 IDIDL
# 17357        Idaho Department of Lands                 IDIDL
# 17358        Idaho Department of Lands                 IDIDL
# 17359        Idaho Department of Lands                 IDIDL
#
#             SOURCE_REPORTING_UNIT_NAME  ...   LONGITUDE OWNER_CODE  \
# 0      Caribou-Targhee National Forest  ... -111.256111        5.0
# 1      Caribou-Targhee National Forest  ... -112.384444        5.0
# 2      Caribou-Targhee National Forest  ... -112.176667        5.0
# 3      Caribou-Targhee National Forest  ... -112.368611        5.0
# 4      Caribou-Targhee National Forest  ... -112.072222        5.0
# ...                                ...  ...         ...        ...
# 17355        Idaho Department of Lands  ... -116.788012        8.0
# 17356        Idaho Department of Lands  ... -116.348913        8.0
# 17357        Idaho Department of Lands  ... -116.392942        8.0
# 17358        Idaho Department of Lands  ... -116.088832        8.0
# 17359        Idaho Department of Lands  ... -116.474317        8.0
#
#       OWNER_DESCR STATE    COUNTY FIPS_CODE FIPS_NAME  Shape  \
# 0            USFS    ID        43        43   Fremont  Point
# 1            USFS    ID         5         5   Bannock  Point
# 2            USFS    ID         5         5   Bannock  Point
# 3            USFS    ID         5         5   Bannock  Point
# 4            USFS    ID         5         5   Bannock  Point
# ...           ...   ...       ...       ...       ...    ...
# 17355     PRIVATE    ID  Kootenai        55  Kootenai  Point
# 17356     PRIVATE    ID  Boundary        21  Boundary  Point
# 17357     PRIVATE    ID  Boundary        21  Boundary  Point
# 17358     PRIVATE    ID    Valley        85    Valley  Point
# 17359     PRIVATE    ID  Boundary        21  Boundary  Point
#
#       DISCOVERY_DATE_CONVERTED  CONT_DATE_CONVERTED
# 0                   2005-07-16           2005-07-16
# 1                   2005-07-02           2005-07-02
# 2                   2005-07-04           2005-07-04
# 3                   2005-07-04           2005-07-04
# 4                   2005-07-07           2005-07-07
# ...                        ...                  ...
# 17355               2015-10-06           2015-10-07
# 17356               2015-10-11           2015-10-12
# 17357               2015-10-12           2015-10-12
# 17358               2015-10-14           2015-10-14
# 17359               2015-10-17           2015-10-18
#
# [17360 rows x 39 columns]

# %% [markdown]
# ## DATA CLEAN UP AND REMOVE UNWANTED COLUMNS

# %%
# CREATE COLUMNS WE NEED
fires_Idaho_df['FIRE_DAYS'] = (((fires_Idaho_df['CONT_DOY']) + 1) - fires_Idaho_df['DISCOVERY_DOY'])
fires_Idaho_df['COUNTY_NAME'] = (fires_Idaho_df['FIPS_NAME'])

# DELETE COLUMNS WE DO NOT NEED
fires_Idaho_df_cropped = fires_Idaho_df.drop(['OBJECTID', 'FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE', 'SOURCE_SYSTEM', 'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID', 
                                              'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT', 'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID', 'LOCAL_INCIDENT_ID', 
                                              'FIRE_CODE', 'FIRE_NAME', 'ICS_209_INCIDENT_NUMBER', 'ICS_209_NAME', 'MTBS_ID', 'MTBS_FIRE_NAME', 'COMPLEX_NAME', 'DISCOVERY_DOY', 
                                              'DISCOVERY_TIME', 'STAT_CAUSE_CODE', 'CONT_DOY','CONT_TIME', 'OWNER_CODE', 'OWNER_DESCR', 'STATE', 'Shape'], axis=1)

# DELETE ROWS WE DO NOT NEED
fires_Idaho_2000_2015_df = fires_Idaho_df_cropped.loc[(fires_Idaho_df["FIRE_YEAR"] >= 1999)] 

clean_fires_Idaho_2000_2015_df.isnull().sum()
# Out:
# FIRE_YEAR                             0
# CONT_DOY                              0
# FIRE_SIZE                             0
# FIRE_SIZE_CLASS                       0
# LATITUDE                              0
# LONGITUDE                             0
# COUNTY                                0
# FIPS_CODE                             0
# FIPS_NAME                             0
# DISCOVERY_DATE_CONVERTED              0
# CONT_DATE_CONVERTED                   0
# STAT_CAUSE_DESCR_Arson                0
# STAT_CAUSE_DESCR_Campfire             0
# STAT_CAUSE_DESCR_Children             0
# STAT_CAUSE_DESCR_Debris Burning       0
# STAT_CAUSE_DESCR_Equipment Use        0
# STAT_CAUSE_DESCR_Fireworks            0
# STAT_CAUSE_DESCR_Lightning            0
# STAT_CAUSE_DESCR_Miscellaneous        0
# STAT_CAUSE_DESCR_Missing/Undefined    0
# STAT_CAUSE_DESCR_Powerline            0
# STAT_CAUSE_DESCR_Railroad             0
# STAT_CAUSE_DESCR_Smoking              0
# STAT_CAUSE_DESCR_Structure            0
# dtype: int64

# %%
# Get dummy variables for nominal property column
clean_fires_Idaho_2000_2015_df = pd.get_dummies(fires_Idaho_2000_2015_df, columns=["STAT_CAUSE_DESCR"])


clean_fires_Idaho_2000_2015_df.isnull().sum()

# %% [markdown]
# ### Generate and associate cities using the lat lng coordinates

# %%
# from citipy import citipy

# # Pull lat lng columns from df
# location_df = fires_Idaho_df[['LATITUDE', 'LONGITUDE']]

# %%
# ### Generate a random cities from Lat Long table make sure we have up to 500. Delete any duplicates: 
# # Make lists needed
# cityList = []
# countryList = []

# # Create a loop to find a city for each lat long pair
# for index, row in location_df.iterrows():
# #     print(f"Searching for nearest city to lat long {row['Latitude'], row['Longitude']}...")
#     city = citipy.nearest_city(row["LATITUDE"], row["LONGITUDE"])
#     cityName = city.city_name
#     location_df.loc[index,"CITY"] = cityName
#     cityList.append(cityName)

# %%
# location_df

# %%
# location_df['CITY'].value_counts()
# # location_df['CITY'].unique()

# %% [markdown]
# ## INPUT HISTORIC WEATHER DATA

# %% [markdown]
# # MODELING

# %% [markdown]
# ## CREATING A NEURAL NETWORK MODEL

# %%
fires_Idaho_2000_2015_df
# Out:
#        FIRE_YEAR STAT_CAUSE_DESCR  CONT_DOY  FIRE_SIZE FIRE_SIZE_CLASS  \
# 0           2005    Miscellaneous       197       0.10               A
# 1           2005         Campfire       183       0.10               A
# 2           2005         Campfire       185       0.10               A
# 3           2005         Campfire       185       0.10               A
# 4           2005         Campfire       188       0.10               A
# ...          ...              ...       ...        ...             ...
# 17355       2015    Miscellaneous       280       0.45               B
# 17356       2015    Miscellaneous       285       0.10               A
# 17357       2015    Miscellaneous       285       0.10               A
# 17358       2015    Miscellaneous       287       0.10               A
# 17359       2015    Miscellaneous       291       0.10               A
#
#         LATITUDE   LONGITUDE    COUNTY  FIPS_CODE FIPS_NAME  \
# 0      44.488611 -111.256111        43         43   Fremont
# 1      42.736389 -112.384444         5          5   Bannock
# 2      42.839722 -112.176667         5          5   Bannock
# 3      42.691389 -112.368611         5          5   Bannock
# 4      42.736389 -112.072222         5          5   Bannock
# ...          ...         ...       ...        ...       ...
# 17355  47.833579 -116.788012  Kootenai         55  Kootenai
# 17356  48.769787 -116.348913  Boundary         21  Boundary
# 17357  48.589271 -116.392942  Boundary         21  Boundary
# 17358  44.491862 -116.088832    Valley         85    Valley
# 17359  48.636208 -116.474317  Boundary         21  Boundary
#
#       DISCOVERY_DATE_CONVERTED CONT_DATE_CONVERTED
# 0                   2005-07-16          2005-07-16
# 1                   2005-07-02          2005-07-02
# 2                   2005-07-04          2005-07-04
# 3                   2005-07-04          2005-07-04
# 4                   2005-07-07          2005-07-07
# ...                        ...                 ...
# 17355               2015-10-06          2015-10-07
# 17356               2015-10-11          2015-10-12
# 17357               2015-10-12          2015-10-12
# 17358               2015-10-14          2015-10-14
# 17359               2015-10-17          2015-10-18
#
# [16527 rows x 12 columns]

# %%
# CREATE X VALUES
X = clean_fires_Idaho_2000_2015_df.drop(['FIRE_SIZE', 'FIRE_SIZE_CLASS'], axis=1)
print(X.keys())
X = X.values.reshape(-1, 11)

# X = X.to_numpy()


print(X.shape)
type(X)
X

# fires_Idaho_2000_2015_df



X1 = fire()
X2 = weather_df
# Out:
# Index(['FIRE_YEAR', 'CONT_DOY', 'LATITUDE', 'LONGITUDE', 'COUNTY', 'FIPS_CODE',
#        'FIPS_NAME', 'DISCOVERY_DATE_CONVERTED', 'CONT_DATE_CONVERTED',
#        'STAT_CAUSE_DESCR_Arson', 'STAT_CAUSE_DESCR_Campfire',
#        'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
#        'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
#        'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous',
#        'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',
#        'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
#        'STAT_CAUSE_DESCR_Structure'],
#       dtype='object')
# (33054, 11)
# array([[2005, 197, 44.48861111, ..., '2005-07-16', 0, 0],
#        [0, 0, 0, ..., 0, 0, 0],
#        [2005, 183, 42.73638889, ..., '2005-07-02', 0, 1],
#        ...,
#        [0, 0, 0, ..., 0, 0, 0],
#        [2015, 291, 48.63620768, ..., '2015-10-18', 0, 0],
#        [0, 0, 0, ..., 0, 0, 0]], dtype=object)

# %%
# CREATE y VALUES
y = fires_Idaho_2000_2015_df[['FIRE_SIZE_CLASS']]

y = y.values.reshape(-1, 1)

print(y.shape)
# type(y)
y

# # LABEL ENCODE Y
# # Import required module
# from sklearn.preprocessing import LabelEncoder

# # LabelEncoder
# le = LabelEncoder()

# # Create an object of the label encoder class
# labelencoder = LabelEncoder()

# # apply "le.fit_transform"
# old_y = Y[1].apply(le.fit_transform)
# y = old_y

# # # Change the shape of y v1
# new_y = np.array(old_y)
# y = new_y.reshape(-1, 1) 

# y
# Out:
# (16527, 1)
# array([['A'],
#        ['A'],
#        ['A'],
#        ...,
#        ['A'],
#        ['A'],
#        ['A']], dtype=object)

# %%
# Split data into train and test groups
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e1dda51bed94> in <module>
#       1 # Split data into train and test groups
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2094         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2095
# -> 2096     arrays = indexable(*arrays)
#    2097
#    2098     n_samples = _num_samples(arrays[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     228         else:
#     229             result.append(np.array(X))
# --> 230     check_consistent_length(*result)
#     231     return result
#     232
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [33054, 16527]

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
# y_scaler = StandardScaler().fit(y_train)

# Create variables to hold the scaled train & test data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# y_train_scaled = y_scaler.transform(y_train)
# y_test_scaled = y_scaler.transform(y_test)

# %%
### Encode the categorical target variable to the necessary format for the model
from keras.utils import to_categorical

# One-hot encoding
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %% [markdown]
# ### Create 2 neural network with 1 hidden layer and 2 hidden layers

# %%
# Normal neural network with X inputs, 1 hidden layer, 10 nodes in hidden layer, and 7 outputs
from keras.models import Sequential
from keras.layers import Dense

fire_model_v1 = Sequential()
fire_model_v1.add(Dense(units=10, activation='sigmoid', input_dim=2))
fire_model_v1.add(Dense(units=7, activation='softmax'))

# view the model's architecture
fire_model_v1.summary()

# %%
## Compile and train the deep learning model
fire_model_v1.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

fire_model_v1.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)

# %%
# PLOT MODEL ACCURACY
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(15,4))

ax[0].plot(model_history.history['loss'])
ax[0].set_xlabel("Epochs")
ax[0].set_title("Loss")

ax[1].plot(model_history.history['accuracy'])
ax[1].set_xlabel("Epochs")
ax[1].set_title("Accuracy")

# %%
# Deep neural network with X inputs, 2 hidden layers, 10 nodes in each hidden layer, and 7 outputs
from keras.models import Sequential
from keras.layers import Dense

fire_model_v2 = Sequential()
fire_model_v2.add(Dense(units=10, activation='sigmoid', input_dim=2))
fire_model_v2.add(Dense(units=10, activation='sigmoid'))
fire_model_v2.add(Dense(units=7, activation='softmax'))

# view the model's architecture
fire_model_v2.summary()

# %%
## Compile and train the deep learning model
fire_model_v2.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

fire_model_v2.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)

# %%
# PLOT MODEL ACCURACY
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(15,4))

ax[0].plot(model_history.history['loss'])
ax[0].set_xlabel("Epochs")
ax[0].set_title("Loss")

ax[1].plot(model_history.history['accuracy'])
ax[1].set_xlabel("Epochs")
ax[1].set_title("Accuracy")

# %%
fire_model_v1, fire_model_v1 = fire_model_v1.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

fire_model_v2, fire_model_v2 = fire_model_v2.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {deep_model_loss}, Accuracy: {deep_model_accuracy}")
